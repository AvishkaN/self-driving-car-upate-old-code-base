# %%
! uv pip show numpy
# Out:
# Name: numpy
# Version: 2.2.6
# Location: C:\Users\Admin\Desktop\works\13_self_driving_car\.venv\Lib\site-packages
# Requires:
# Required-by: contourpy, h5py, keras, matplotlib, ml-dtypes, opencv-contrib-python, tensorflow

# %%
! uv pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.21.0
# Location: C:\Users\Admin\Desktop\works\13_self_driving_car\.venv\Lib\site-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, requests, setuptools, six, termcolor, typing-extensions, wrapt
# Required-by:

# %%
! uv pip show keras
# Out:
# Name: keras
# Version: 3.12.4
# Location: C:\Users\Admin\Desktop\works\13_self_driving_car\.venv\Lib\site-packages
# Requires: absl-py, h5py, ml-dtypes, namex, numpy, optree, packaging, rich
# Required-by: tensorflow

# %%
# !git clone https://github.com/rslim087a/track

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
from tensorflow import keras
import tensorflow as tf

# %%
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D, Dropout, Flatten, Dense, Conv2D

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
import cv2
import pandas as pd
import ntpath
import random

# %%
import numpy as np
if not hasattr(np, "sctypes"):
    np.sctypes = {
        "float": [np.float16, np.float32, np.float64],
        "int": [np.int8, np.int16, np.int32, np.int64],
        "uint": [np.uint8, np.uint16, np.uint32, np.uint64],
        "complex": [np.complex64, np.complex128],
        "others": [bool, object, bytes, str, np.void],
    }

from imgaug import augmenters as iaa

# %%
datadir = 'track'
columns = ['center', 'left', 'right', 'steering', 'throttle', 'reverse', 'speed']
data = pd.read_csv(os.path.join(datadir, 'driving_log.csv'), names = columns)
pd.set_option('display.max_colwidth', -1)
data.head()
